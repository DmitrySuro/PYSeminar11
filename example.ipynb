# %%
import math
from sympy import *

from sympy.plotting import plot as plt
init_printing()

x = Symbol('x')
fx = 5*x**2 + 10*x - 30

fx
# Out:
#    2
# 5⋅x  + 10⋅x - 30

# %% [markdown]
# **Построение графика**

# %%
p = plt(fx, (x, -5, 5))

# %% [markdown]
# **Вычисляем вершину**

# %%
from sympy import minimum, maximum, Interval

interv = Interval(-5, 5)
res_min = minimum(fx, interv)
res_max = maximum(fx, interv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 4
#       1 from sympy.calculus.util import minimum, maximum, Interval
#       3 interv = Interval(-5,5)
# ----> 4 res_min = minimum(fx, interv)
#       5 res_max = maximum(fx, interv)
#
# File c:\Users\Пользователь\AppData\Local\Programs\Python\Python311\Lib\site-packages\sympy\calculus\util.py:843, in minimum(f, symbol, domain)
#     841     return function_range(f, symbol, domain).inf
#     842 else:
# --> 843     raise ValueError("%s is not a valid symbol." % symbol)
#
# ValueError: Interval(-5, 5) is not a valid symbol.

# %% [markdown]
# **Нашли вершину**

# %%
solve(diff(fx))
# Out:
# [-1]

# %% [markdown]
# **Промежуток где f>0**

# %%
solve(diff(fx) > 0)
print(solve(fx > 0))
# Out:
# ((x < oo) & (-1 + sqrt(7) < x)) | ((-oo < x) & (x < -sqrt(7) - 1))

# %% [markdown]
# **Промежуток где f<0**

# %%
solve(diff(fx) < 0)
print(solve(fx < 0))
# Out:
# (x < -1 + sqrt(7)) & (-sqrt(7) - 1 < x)
